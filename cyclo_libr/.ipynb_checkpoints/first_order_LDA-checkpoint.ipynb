# %%
#%matplotlib notebook
import h5py, pickle
import numpy as np
import numpy
import matplotlib.pyplot as plt
import matplotlib.cm as cm
from sklearn.model_selection import train_test_split
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis as LDA
from sklearn.linear_model import LogisticRegression as LRG
from sklearn.decomposition import PCA
import lib.fot as fot
import lib.sot as crr
import lib.hos as hos
from scipy import signal

mods_ = ['OOK', '4ASK', '8ASK', 'BPSK', 'QPSK', '8PSK', '16PSK', '32PSK', '16APSK',\
         '32APSK', '64APSK', '128APSK', '16QAM', '32QAM', '64QAM', '128QAM', \
         '256QAM', 'AM-SSB-WC', 'AM-SSB-SC', 'AM-DSB-WC', 'AM-DSB-SC', 'FM', 'GMSK', 'OQPSK']
mod = [i for i in range(0, 24) if i not in [17,18,19,20,21]]  # all digital mods.

hf = h5py.File('../dataset/201801a_data_test.h5', 'r+')
x = hf['test']
p = int(len(x) / 24)
pp = int(p / 26)
pts = 200
# x_train, x_test, y_train, y_test = train_test_split(xx, yy, test_size=0.15, random_state=42, stratify=yy)

# %% [markdown]
# ## STFT.

# %%
snr = range(0,8)

xx = []
for i in mod:
    for j in snr:
        base = i*p + j*pp + 2
        s = x[base:(base + pts),:,0] + 1j*x[base:(base + pts),:,1]
        # x, fs=1.0, window='hann', nperseg=256, noverlap=None
        # return_onesided=True, boundary='zeros', padded=True, axis=- 1
        _, __, data = signal.stft(s, noverlap=128, return_onesided=False)
        data = data.reshape((pts, -1))
        xx.append(abs(data))
    print (mods_[i])
xx = np.asarray(xx).reshape((-1, data.shape[-1]))
print (xx.shape)

yy = []
for i in range(len(mod)):
    yy.append([i] * int(pts * len(snr)))
yy = np.hstack(yy)
print (yy.shape)

lda = LDA().fit(xx, yy)
lda.score(xx, yy)
# Out:
# OOK
# 4ASK
# 8ASK
# BPSK
# QPSK
# 8PSK
# 16PSK
# 32PSK
# 16APSK
# 32APSK
# 64APSK
# 128APSK
# 16QAM
# 32QAM
# 64QAM
# 128QAM
# 256QAM
# GMSK
# OQPSK
# (30400, 2304)
# (30400,)
# 0.3375657894736842

# %%
snr = range(8,16)

xx = []
for i in mod:
    for j in snr:
        base = i*p + j*pp + 2
        s = x[base:(base + pts),:,0] + 1j*x[base:(base + pts),:,1]
        # x, fs=1.0, window='hann', nperseg=256, noverlap=None
        # return_onesided=True, boundary='zeros', padded=True, axis=- 1
        _, __, data = signal.stft(s, noverlap=128, return_onesided=False)
        data = data.reshape((pts, -1))
        xx.append(abs(data))
    print (mods_[i])
xx = np.asarray(xx).reshape((-1, data.shape[-1]))
print (xx.shape)

yy = []
for i in range(len(mod)):
    yy.append([i] * int(pts * len(snr)))
yy = np.hstack(yy)
print (yy.shape)

lda = LDA().fit(xx, yy)
lda.score(xx, yy)
# Out:
# OOK
# 4ASK
# 8ASK
# BPSK
# QPSK
# 8PSK
# 16PSK
# 32PSK
# 16APSK
# 32APSK
# 64APSK
# 128APSK
# 16QAM
# 32QAM
# 64QAM
# 128QAM
# 256QAM
# GMSK
# OQPSK
# (30400, 2304)
# (30400,)
# 0.4087171052631579

# %%
snr = range(16,26)

xx = []
for i in mod:
    for j in snr:
        base = i*p + j*pp + 2
        s = x[base:(base + pts),:,0] + 1j*x[base:(base + pts),:,1]
        # x, fs=1.0, window='hann', nperseg=256, noverlap=None
        # return_onesided=True, boundary='zeros', padded=True, axis=- 1
        _, __, data = signal.stft(s, noverlap=128, return_onesided=False)
        data = data.reshape((pts, -1))
        xx.append(abs(data))
    print (mods_[i])
xx = np.asarray(xx).reshape((-1, data.shape[-1]))
print (xx.shape)

yy = []
for i in range(len(mod)):
    yy.append([i] * int(pts * len(snr)))
yy = np.hstack(yy)
print (yy.shape)

lda = LDA().fit(xx, yy)
lda.score(xx, yy)
# Out:
# OOK
# 4ASK
# 8ASK
# BPSK
# QPSK
# 8PSK
# 16PSK
# 32PSK
# 16APSK
# 32APSK
# 64APSK
# 128APSK
# 16QAM
# 32QAM
# 64QAM
# 128QAM
# 256QAM
# GMSK
# OQPSK
# (38000, 2304)
# (38000,)
# 0.43

# %% [markdown]
# ## FFT.

# %%
snr = range(0,8)

xx = []
for i in mod:
    for j in snr:
        base = i*p + j*pp + 2
        s = x[base:(base + pts),:,0] + 1j*x[base:(base + pts),:,1]
        data = fot.FT(s)
        xx.append(data)
    print (mods_[i])
xx = np.asarray(xx).reshape((-1,data.shape[-1]))
print (xx.shape)

yy = []
for i in range(len(mod)):
    yy.append([i] * int(pts * len(snr)))
yy = np.hstack(yy)
print (yy.shape)

lda = LDA().fit(xx, yy)
lda.score(xx, yy)
# Out:
# OOK
# 4ASK
# 8ASK
# BPSK
# QPSK
# 8PSK
# 16PSK
# 32PSK
# 16APSK
# 32APSK
# 64APSK
# 128APSK
# 16QAM
# 32QAM
# 64QAM
# 128QAM
# 256QAM
# GMSK
# OQPSK
# (30400, 1024)
# (30400,)
# 0.21743421052631579

# %%
snr = range(8,16)

xx = []
for i in mod:
    for j in snr:
        base = i*p + j*pp + 2
        s = x[base:(base + pts),:,0] + 1j*x[base:(base + pts),:,1]
        data = fot.FT(s)
        xx.append(abs(data))
    print (mods_[i])
xx = np.asarray(xx).reshape((-1,data.shape[-1]))
print (xx.shape)

yy = []
for i in range(len(mod)):
    yy.append([i] * int(pts * len(snr)))
yy = np.hstack(yy)
print (yy.shape)

lda = LDA().fit(xx, yy)
lda.score(xx, yy)
# Out:
# OOK
# 4ASK
# 8ASK
# BPSK
# QPSK
# 8PSK
# 16PSK
# 32PSK
# 16APSK
# 32APSK
# 64APSK
# 128APSK
# 16QAM
# 32QAM
# 64QAM
# 128QAM
# 256QAM
# GMSK
# OQPSK
# (30400, 1024)
# (30400,)
# 0.28601973684210524

# %%
snr = range(16,26)

xx = []
for i in mod:
    for j in snr:
        base = i*p + j*pp + 2
        s = x[base:(base + pts),:,0] + 1j*x[base:(base + pts),:,1]
        data = fot.FT(s)
        xx.append(abs(data))
    print (mods_[i])
xx = np.asarray(xx).reshape((-1,data.shape[-1]))
print (xx.shape)

yy = []
for i in range(len(mod)):
    yy.append([i] * int(pts * len(snr)))
yy = np.hstack(yy)
print (yy.shape)

lda = LDA().fit(xx, yy)
lda.score(xx, yy)
# Out:
# OOK
# 4ASK
# 8ASK
# BPSK
# QPSK
# 8PSK
# 16PSK
# 32PSK
# 16APSK
# 32APSK
# 64APSK
# 128APSK
# 16QAM
# 32QAM
# 64QAM
# 128QAM
# 256QAM
# GMSK
# OQPSK
# (38000, 1024)
# (38000,)
# 0.3369473684210526

# %% [markdown]
# ## Level 1 Haar DWT

# %%
snr = range(16,26)

waveletname = 'haar'   # 'gaus1' 
xx = []
for i in mod:
    for j in snr:
        base = i*p + j*pp + 2
        s = x[base:(base + pts),:,0] + 1j*x[base:(base + pts),:,1]
        s = fot.DWT(s, waveletname)
        xx.append(abs(s))
    print (mods_[i])
xx = np.asarray(xx).reshape((-1, s.shape[-1]))
print (xx.shape)

yy = []
for i in range(len(mod)):
    yy.append([i] * int(pts * len(snr)))
yy = np.hstack(yy)
print (yy.shape)
# Out:
# OOK
# 4ASK
# 8ASK
# BPSK
# QPSK
# 8PSK
# 16PSK
# 32PSK
# 16APSK
# 32APSK
# 64APSK
# 128APSK
# 16QAM
# 32QAM
# 64QAM
# 128QAM
# 256QAM
# GMSK
# OQPSK
# (38000, 1024)
# (38000,)

# %%
lda = LDA().fit(xx, yy)
lda.score(xx, yy)
# Out:
# 0.36657894736842106

# %% [markdown]
# ## CWT
# ### SNR -5 to +10 dB.

# %%
import pywt
print (pywt.wavelist(kind='continuous'))
# Out:
# ['cgau1', 'cgau2', 'cgau3', 'cgau4', 'cgau5', 'cgau6', 'cgau7', 'cgau8', 'cmor', 'fbsp', 'gaus1', 'gaus2', 'gaus3', 'gaus4', 'gaus5', 'gaus6', 'gaus7', 'gaus8', 'mexh', 'morl', 'shan']

# %%
snr = range(0,8)

waveletname = 'gaus1' # 'haar'
xx = []
for i in mod:
    for j in snr:
        base = i*p + j*pp + 2
        s = x[base:(base + pts),:,0] + 1j*x[base:(base + pts),:,1]
        (data, _) = fot.CWT(s, waveletname)
        xx.append(data[-1,:,:])
        #print (data[-1,:,:].shape)
    print (mods_[i])
xx = np.asarray(xx).reshape((-1,data.shape[-1]))
print (xx.shape)

yy = []
for i in range(len(mod)):
    yy.append([i] * int(pts * len(snr)))
yy = np.hstack(yy)
print (yy.shape)

lda = LDA().fit(xx, yy)
lda.score(xx, yy)
# Out:
# OOK
# 4ASK
# 8ASK
# BPSK
# QPSK
# 8PSK
# 16PSK
# 32PSK
# 16APSK
# 32APSK
# 64APSK
# 128APSK
# 16QAM
# 32QAM
# 64QAM
# 128QAM
# 256QAM
# GMSK
# OQPSK
# (30400, 1024)
# (30400,)
# 0.19

# %%
snr = range(8,16)

waveletname = 'gaus1' # 'haar'
xx = []
for i in mod:
    for j in snr:
        base = i*p + j*pp + 2
        s = x[base:(base + pts),:,0] + 1j*x[base:(base + pts),:,1]
        (data, _) = fot.CWT(s, waveletname)
        xx.append(data[-1,:,:])
        #print (data[-1,:,:].shape)
    print (mods_[i])
xx = np.asarray(xx).reshape((-1,data.shape[-1]))
print (xx.shape)

yy = []
for i in range(len(mod)):
    yy.append([i] * int(pts * len(snr)))
yy = np.hstack(yy)
print (yy.shape)

lda = LDA().fit(xx, yy)
lda.score(xx, yy)
# Out:
# OOK
# 4ASK
# 8ASK
# BPSK
# QPSK
# 8PSK
# 16PSK
# 32PSK
# 16APSK
# 32APSK
# 64APSK
# 128APSK
# 16QAM
# 32QAM
# 64QAM
# 128QAM
# 256QAM
# GMSK
# OQPSK
# (30400, 1024)
# (30400,)
# 0.19233552631578948

# %%
snr = range(16,26)

waveletname = 'gaus1' # 'haar'
xx = []
for i in mod:
    for j in snr:
        base = i*p + j*pp + 2
        s = x[base:(base + pts),:,0] + 1j*x[base:(base + pts),:,1]
        (data, _) = fot.CWT(s, waveletname)
        xx.append(data[-1,:,:])
        #print (data[-1,:,:].shape)
    print (mods_[i])
xx = np.asarray(xx).reshape((-1,data.shape[-1]))
print (xx.shape)

yy = []
for i in range(len(mod)):
    yy.append([i] * int(pts * len(snr)))
yy = np.hstack(yy)
print (yy.shape)

lda = LDA().fit(xx, yy)
lda.score(xx, yy)
# Out:
# OOK
# 4ASK
# 8ASK
# BPSK
# QPSK
# 8PSK
# 16PSK
# 32PSK
# 16APSK
# 32APSK
# 64APSK
# 128APSK
# 16QAM
# 32QAM
# 64QAM
# 128QAM
# 256QAM
# GMSK
# OQPSK
# (38000, 1024)
# (38000,)
# 0.22031578947368421

# %%
lda = LDA(n_components=2)
lda = lda.fit(xx, yy)
X_lda = lda.transform(xx)

colors = cm.rainbow(np.linspace(0, 1, len(mod)))
plt.figure(figsize = (7, 7))
plt.scatter(X_lda[:, 0], X_lda[:, 1], alpha=0.6, c=colors[yy])
